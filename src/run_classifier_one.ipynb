# %% [markdown]
# ## Execute this two line when working with anaconda for automatically reload any new version of your code

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import RunClassifiers module for Algorithm Selection

# %%
import selectClassifiers

# %% [markdown]
# ## Run Classifiers for benchmark dataset with all generated feature

# %%
#Number of crossValidation    
pnFCV=10
# dataset.csv
pdataset='fullDataset.csv'
#Print ROC Curve
# 1 for printing 
pauROC= 1
#Print Accuracy Box Plaot
# 1 for printing
pboxPlot = 1
selectClassifiers.runClassifiers(pdataset,pnFCV,pauROC,pboxPlot)
# Out:
# LogisticRegression is done.
# KNeighborsClassifier is done.
# E:\anaconda\lib\site-packages\sklearn\metrics\classification.py:872: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# E:\anaconda\lib\site-packages\sklearn\metrics\classification.py:872: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# E:\anaconda\lib\site-packages\sklearn\metrics\classification.py:872: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# E:\anaconda\lib\site-packages\sklearn\metrics\classification.py:872: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# E:\anaconda\lib\site-packages\sklearn\metrics\classification.py:872: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# ...
